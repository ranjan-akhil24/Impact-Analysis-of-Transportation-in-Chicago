# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd

result_df = pd.read_csv("~/Downloads/Divvy_Trips.csv")

result_df.head()
# Out:
#    TRIP ID              START TIME               STOP TIME  BIKE ID  \
# 0  8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM      979
# 1  8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM     1932
# 2  8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM     1693
# 3  8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM     3370
# 4  8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM     2563
#
#    TRIP DURATION  FROM STATION ID           FROM STATION NAME  TO STATION ID  \
# 0            521              117    Wilton Ave & Belmont Ave            229
# 1            256              301      Clark St & Schiller St            138
# 2            134              465      Marine Dr & Ainslie St            251
# 3            995              333  Ashland Ave & Blackhawk St            198
# 4            177               48  Larrabee St & Kingsbury St            111
#
#                       TO STATION NAME   USER TYPE  GENDER  BIRTH YEAR  \
# ...

# %%
result_df.info
# Out:
# <bound method DataFrame.info of            TRIP ID              START TIME               STOP TIME  BIKE ID  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM      979
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM     1932
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM     1693
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM     3370
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM     2563
# ...            ...                     ...                     ...      ...
# 21242735  25946308  12/27/2019 07:16:35 AM  12/27/2019 07:36:18 AM      577
# 21242736  25953151  12/29/2019 08:07:13 AM  12/29/2019 08:10:37 AM     4251
# 21242737  25953070  12/29/2019 03:30:39 AM  12/29/2019 03:40:31 AM     3113
# 21242738  25948187  12/27/2019 02:40:53 PM  12/27/2019 03:10:42 PM     3947
# 21242739  25951619  12/28/2019 02:03:33 PM  12/30/2019 06:17:01 AM     3321
#
# ...

# %%
print ("Num of rows: " + str(result_df.shape[0])) # row count
# Out:
# Num of rows: 21242740

# %%
print ("Num of columns: " + str(result_df.shape[1])) # col count
# Out:
# Num of columns: 18

# %%
result_df.head()
# Out:
#    TRIP ID              START TIME               STOP TIME  BIKE ID  \
# 0  8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM      979
# 1  8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM     1932
# 2  8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM     1693
# 3  8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM     3370
# 4  8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM     2563
#
#    TRIP DURATION  FROM STATION ID           FROM STATION NAME  TO STATION ID  \
# 0            521              117    Wilton Ave & Belmont Ave            229
# 1            256              301      Clark St & Schiller St            138
# 2            134              465      Marine Dr & Ainslie St            251
# 3            995              333  Ashland Ave & Blackhawk St            198
# 4            177               48  Larrabee St & Kingsbury St            111
#
#                       TO STATION NAME   USER TYPE  GENDER  BIRTH YEAR  \
# ...

# %%
result_df.info
# Out:
# <bound method DataFrame.info of            TRIP ID              START TIME               STOP TIME  BIKE ID  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM      979
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM     1932
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM     1693
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM     3370
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM     2563
# ...            ...                     ...                     ...      ...
# 21242735  25946308  12/27/2019 07:16:35 AM  12/27/2019 07:36:18 AM      577
# 21242736  25953151  12/29/2019 08:07:13 AM  12/29/2019 08:10:37 AM     4251
# 21242737  25953070  12/29/2019 03:30:39 AM  12/29/2019 03:40:31 AM     3113
# 21242738  25948187  12/27/2019 02:40:53 PM  12/27/2019 03:10:42 PM     3947
# 21242739  25951619  12/28/2019 02:03:33 PM  12/30/2019 06:17:01 AM     3321
#
# ...

# %%
#Removing Columns: Birth Year, BikeID, UserType, Gender, From Longitude, From Latitude
not_needed = ['BIRTH YEAR','BIKE ID','USER TYPE','GENDER','FROM LATITUDE','FROM LONGITUDE', 'TO LATITUDE', 'TO LONGITUDE']
results_df=result_df.drop(not_needed, axis=1)

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21242740 entries, 0 to 21242739
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRIP ID            int64
#  1   START TIME         object
#  2   STOP TIME          object
#  3   TRIP DURATION      int64
#  4   FROM STATION ID    int64
#  5   FROM STATION NAME  object
#  6   TO STATION ID      int64
#  7   TO STATION NAME    object
#  8   FROM LOCATION      object
#  9   TO LOCATION        object
# dtypes: int64(4), object(6)
# memory usage: 1.6+ GB

# %%
results_df.head(10)
# Out:
#    TRIP ID              START TIME               STOP TIME  TRIP DURATION  \
# 0  8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM            521
# 1  8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM            256
# 2  8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM            134
# 3  8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM            995
# 4  8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM            177
# 5  8546799  12/31/2015 05:39:00 PM  12/31/2015 05:52:00 PM            808
# 6  8546803  12/31/2015 05:40:00 PM  12/31/2015 05:43:00 PM            194
# 7  8546805  12/31/2015 05:40:00 PM  12/31/2015 05:45:00 PM            309
# 8  8546813  12/31/2015 05:41:00 PM  12/31/2015 05:53:00 PM            674
# 9    10000  06/30/2013 10:46:00 AM  06/30/2013 11:41:00 AM           3260
#
#    FROM STATION ID           FROM STATION NAME  TO STATION ID  \
# 0              117    Wilton Ave & Belmont Ave            229
# ...

# %%
results_df["START TIME"] = pd.to_datetime(results_df["START TIME"])
results_df["START TIME"]
# Out:
# 0          2015-12-31 17:35:00
# 1          2015-12-31 17:37:00
# 2          2015-12-31 17:37:00
# 3          2015-12-31 17:38:00
# 4          2015-12-31 17:38:00
#                    ...
# 21242735   2019-12-27 07:16:35
# 21242736   2019-12-29 08:07:13
# 21242737   2019-12-29 03:30:39
# 21242738   2019-12-27 14:40:53
# 21242739   2019-12-28 14:03:33
# Name: START TIME, Length: 21242740, dtype: datetime64[ns]

# %%
results_df = results_df[results_df['START TIME'] > '2018-01-01']

# %%
results_df.sort_values(by='START TIME', ascending=True)
# Out:
#            TRIP ID          START TIME               STOP TIME  TRIP DURATION  \
# 14936741  17536702 2018-01-01 00:12:00  01/01/2018 12:17:00 AM            323
# 14936948  17536703 2018-01-01 00:41:00  01/01/2018 12:47:00 AM            377
# 14937239  17536704 2018-01-01 00:44:00  01/01/2018 01:33:00 AM           2904
# 14936805  17536706 2018-01-01 00:53:00  01/01/2018 12:56:00 AM            183
# 14937098  17536705 2018-01-01 00:53:00  01/01/2018 01:05:00 AM            747
# ...            ...                 ...                     ...            ...
# 21233559  25962900 2019-12-31 23:56:13  01/01/2020 12:15:45 AM           1172
# 21242258  25962901 2019-12-31 23:56:34  01/01/2020 12:22:08 AM           1533
# 21239395  25962902 2019-12-31 23:57:05  01/01/2020 12:05:46 AM            520
# 21232291  25962903 2019-12-31 23:57:11  01/01/2020 12:05:45 AM            514
# 21228281  25962904 2019-12-31 23:57:17  12/31/2019 11:59:18 PM            120
#
# ...

# %%
results_df.to_csv('Divvy_Trips_Clean.csv')

# %%
import datetime as dt
import time as tm

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7420746 entries, 6729116 to 21242739
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRIP ID            int64
#  1   START TIME         datetime64[ns]
#  2   STOP TIME          object
#  3   TRIP DURATION      int64
#  4   FROM STATION ID    int64
#  5   FROM STATION NAME  object
#  6   TO STATION ID      int64
#  7   TO STATION NAME    object
#  8   FROM LOCATION      object
#  9   TO LOCATION        object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 622.8+ MB
